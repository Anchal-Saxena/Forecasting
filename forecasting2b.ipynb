# %% [markdown]
# #### Upsampling Data

# %%
# upsample to daily intervals
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot

# %%
series = read_csv('../input/sales123/sales.csv', header=0, index_col=0, parse_dates=True,squeeze=True)

# %%
series

# %%
upsampled = series.resample('D').mean()
print(upsampled.head(32))

# %% [markdown]
# ##### interpolate the missing value

# %%
interpolated = upsampled.interpolate(method='linear')
print(interpolated.head(32))
interpolated.plot()
pyplot.show()

# %% [markdown]
# #### Downsampling Data

# %%
# downsample to quarterly intervals
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot

# %%
resample = series.resample('Q')
quarterly_mean_sales = resample.mean()

# %% [markdown]
# # Tranformations

# %%
# load and plot a time series
from pandas import read_csv
from matplotlib import pyplot

# %%
series = read_csv('../input/airlines123/airline-passengers.csv', header=0, index_col=0, parse_dates=True)

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(series)
# histogram
pyplot.subplot(212)
pyplot.hist(series)
pyplot.show()

# %% [markdown]
# #### Square Root Transform

# %%
from pandas import read_csv
from pandas import DataFrame
from numpy import sqrt
from matplotlib import pyplot

# %%
dataframe = DataFrame(series.values)
dataframe.columns = ['passengers']
dataframe['passengers'] = sqrt(dataframe['passengers'])

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(dataframe['passengers'])
# histogram
pyplot.subplot(212)
pyplot.hist(dataframe['passengers'])
pyplot.show()

# %% [markdown]
# #### Log Transform

# %%
from numpy import log
dataframe = DataFrame(series.values)
dataframe.columns = ['passengers']
dataframe['passengers'] = log(dataframe['passengers'])

# line plot
pyplot.subplot(211)
pyplot.plot(dataframe['passengers'])
# histogram
pyplot.subplot(212)
pyplot.hist(dataframe['passengers'])
pyplot.show()

# %%
print(quarterly_mean_sales.head())
quarterly_mean_sales.plot()
pyplot.show()
